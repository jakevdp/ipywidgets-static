# %% [markdown]
# # Static Interactive Notebook
#
# This notebook shows a few examples of what's possible with the static widgets

# %% [markdown]
# ## Example 1: Simple Text output

# %%
from ipywidgets import StaticInteract, RangeWidget, RadioWidget

def multiply(a, b):
    return "{0} * {1} = {2}".format(a, b, a * b)

StaticInteract(multiply,
               a=RangeWidget(0, 10),
               b=RangeWidget(0, 10))
# Out:
#     <script type="text/javascript">
#       function interactUpdate(div){
#          var outputs = div.getElementsByTagName("div");
#          var controls = div.getElementsByTagName("input");
#
#          var value = "";
#          for(i=0; i<controls.length; i++){
#            if((controls[i].type == "range") || controls[i].checked){
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }
#          }
#
#          for(i=0; i<outputs.length; i++){
#            var name = outputs[i].getAttribute("name");
#            if(name == value){
#               outputs[i].style.display = 'block';
#            } else if(name != "controls"){
#               outputs[i].style.display = 'none';
#            }
#          }
#       }
#     </script>
#
#     <div>
#
#     <div name="a0b0" style="display:block">
#       <p> 0 * 0 = 0 </p>
#     </div>
#
#     <div name="a0b1" style="display:none">
#       <p> 0 * 1 = 0 </p>
#     </div>
#
#     <div name="a0b2" style="display:none">
#       <p> 0 * 2 = 0 </p>
#     </div>
#
#     <div name="a0b3" style="display:none">
#       <p> 0 * 3 = 0 </p>
#     </div>
#
#     <div name="a0b4" style="display:none">
#       <p> 0 * 4 = 0 </p>
#     </div>
#
#     <div name="a0b5" style="display:none">
#       <p> 0 * 5 = 0 </p>
#     </div>
#
#     <div name="a0b6" style="display:none">
#       <p> 0 * 6 = 0 </p>
#     </div>
#
#     <div name="a0b7" style="display:none">
#       <p> 0 * 7 = 0 </p>
#     </div>
#
#     <div name="a0b8" style="display:none">
#       <p> 0 * 8 = 0 </p>
#     </div>
#
#     <div name="a0b9" style="display:none">
#       <p> 0 * 9 = 0 </p>
#     </div>
#
#     <div name="a0b10" style="display:none">
#       <p> 0 * 10 = 0 </p>
#     </div>
#
#     <div name="a1b0" style="display:none">
#       <p> 1 * 0 = 0 </p>
#     </div>
#
#     <div name="a1b1" style="display:none">
#       <p> 1 * 1 = 1 </p>
#     </div>
#
#     <div name="a1b2" style="display:none">
#       <p> 1 * 2 = 2 </p>
#     </div>
#
#     <div name="a1b3" style="display:none">
#       <p> 1 * 3 = 3 </p>
#     </div>
#
#     <div name="a1b4" style="display:none">
#       <p> 1 * 4 = 4 </p>
#     </div>
#
#     <div name="a1b5" style="display:none">
#       <p> 1 * 5 = 5 </p>
#     </div>
#
#     <div name="a1b6" style="display:none">
#       <p> 1 * 6 = 6 </p>
#     </div>
#
#     <div name="a1b7" style="display:none">
#       <p> 1 * 7 = 7 </p>
#     </div>
#
#     <div name="a1b8" style="display:none">
#       <p> 1 * 8 = 8 </p>
#     </div>
#
#     <div name="a1b9" style="display:none">
#       <p> 1 * 9 = 9 </p>
#     </div>
#
#     <div name="a1b10" style="display:none">
#       <p> 1 * 10 = 10 </p>
#     </div>
#
#     <div name="a2b0" style="display:none">
#       <p> 2 * 0 = 0 </p>
#     </div>
#
#     <div name="a2b1" style="display:none">
#       <p> 2 * 1 = 2 </p>
#     </div>
#
#     <div name="a2b2" style="display:none">
#       <p> 2 * 2 = 4 </p>
#     </div>
#
#     <div name="a2b3" style="display:none">
#       <p> 2 * 3 = 6 </p>
#     </div>
#
#     <div name="a2b4" style="display:none">
#       <p> 2 * 4 = 8 </p>
#     </div>
#
#     <div name="a2b5" style="display:none">
#       <p> 2 * 5 = 10 </p>
#     </div>
#
#     <div name="a2b6" style="display:none">
#       <p> 2 * 6 = 12 </p>
#     </div>
#
#     <div name="a2b7" style="display:none">
#       <p> 2 * 7 = 14 </p>
#     </div>
#
#     <div name="a2b8" style="display:none">
#       <p> 2 * 8 = 16 </p>
#     </div>
#
#     <div name="a2b9" style="display:none">
#       <p> 2 * 9 = 18 </p>
#     </div>
#
#     <div name="a2b10" style="display:none">
#       <p> 2 * 10 = 20 </p>
#     </div>
#
#     <div name="a3b0" style="display:none">
#       <p> 3 * 0 = 0 </p>
#     </div>
#
#     <div name="a3b1" style="display:none">
#       <p> 3 * 1 = 3 </p>
#     </div>
#
#     <div name="a3b2" style="display:none">
#       <p> 3 * 2 = 6 </p>
#     </div>
#
#     <div name="a3b3" style="display:none">
#       <p> 3 * 3 = 9 </p>
#     </div>
#
#     <div name="a3b4" style="display:none">
#       <p> 3 * 4 = 12 </p>
#     </div>
#
#     <div name="a3b5" style="display:none">
#       <p> 3 * 5 = 15 </p>
#     </div>
#
#     <div name="a3b6" style="display:none">
#       <p> 3 * 6 = 18 </p>
#     </div>
#
#     <div name="a3b7" style="display:none">
#       <p> 3 * 7 = 21 </p>
#     </div>
#
#     <div name="a3b8" style="display:none">
#       <p> 3 * 8 = 24 </p>
#     </div>
#
#     <div name="a3b9" style="display:none">
#       <p> 3 * 9 = 27 </p>
#     </div>
#
#     <div name="a3b10" style="display:none">
#       <p> 3 * 10 = 30 </p>
#     </div>
#
#     <div name="a4b0" style="display:none">
#       <p> 4 * 0 = 0 </p>
#     </div>
#
#     <div name="a4b1" style="display:none">
#       <p> 4 * 1 = 4 </p>
#     </div>
#
#     <div name="a4b2" style="display:none">
#       <p> 4 * 2 = 8 </p>
#     </div>
#
#     <div name="a4b3" style="display:none">
#       <p> 4 * 3 = 12 </p>
#     </div>
#
#     <div name="a4b4" style="display:none">
#       <p> 4 * 4 = 16 </p>
#     </div>
#
#     <div name="a4b5" style="display:none">
#       <p> 4 * 5 = 20 </p>
#     </div>
#
#     <div name="a4b6" style="display:none">
#       <p> 4 * 6 = 24 </p>
#     </div>
#
#     <div name="a4b7" style="display:none">
#       <p> 4 * 7 = 28 </p>
#     </div>
#
#     <div name="a4b8" style="display:none">
#       <p> 4 * 8 = 32 </p>
#     </div>
#
#     <div name="a4b9" style="display:none">
#       <p> 4 * 9 = 36 </p>
#     </div>
#
#     <div name="a4b10" style="display:none">
#       <p> 4 * 10 = 40 </p>
#     </div>
#
#     <div name="a5b0" style="display:none">
#       <p> 5 * 0 = 0 </p>
#     </div>
#
#     <div name="a5b1" style="display:none">
#       <p> 5 * 1 = 5 </p>
#     </div>
#
#     <div name="a5b2" style="display:none">
#       <p> 5 * 2 = 10 </p>
#     </div>
#
#     <div name="a5b3" style="display:none">
#       <p> 5 * 3 = 15 </p>
#     </div>
#
#     <div name="a5b4" style="display:none">
#       <p> 5 * 4 = 20 </p>
#     </div>
#
#     <div name="a5b5" style="display:none">
#       <p> 5 * 5 = 25 </p>
#     </div>
#
#     <div name="a5b6" style="display:none">
#       <p> 5 * 6 = 30 </p>
#     </div>
#
#     <div name="a5b7" style="display:none">
#       <p> 5 * 7 = 35 </p>
#     </div>
#
#     <div name="a5b8" style="display:none">
#       <p> 5 * 8 = 40 </p>
#     </div>
#
#     <div name="a5b9" style="display:none">
#       <p> 5 * 9 = 45 </p>
#     </div>
#
#     <div name="a5b10" style="display:none">
#       <p> 5 * 10 = 50 </p>
#     </div>
#
#     <div name="a6b0" style="display:none">
#       <p> 6 * 0 = 0 </p>
#     </div>
#
#     <div name="a6b1" style="display:none">
#       <p> 6 * 1 = 6 </p>
#     </div>
#
#     <div name="a6b2" style="display:none">
#       <p> 6 * 2 = 12 </p>
#     </div>
#
#     <div name="a6b3" style="display:none">
#       <p> 6 * 3 = 18 </p>
#     </div>
#
#     <div name="a6b4" style="display:none">
#       <p> 6 * 4 = 24 </p>
#     </div>
#
#     <div name="a6b5" style="display:none">
#       <p> 6 * 5 = 30 </p>
#     </div>
#
#     <div name="a6b6" style="display:none">
#       <p> 6 * 6 = 36 </p>
#     </div>
#
#     <div name="a6b7" style="display:none">
#       <p> 6 * 7 = 42 </p>
#     </div>
#
#     <div name="a6b8" style="display:none">
#       <p> 6 * 8 = 48 </p>
#     </div>
#
#     <div name="a6b9" style="display:none">
#       <p> 6 * 9 = 54 </p>
#     </div>
#
#     <div name="a6b10" style="display:none">
#       <p> 6 * 10 = 60 </p>
#     </div>
#
#     <div name="a7b0" style="display:none">
#       <p> 7 * 0 = 0 </p>
#     </div>
#
#     <div name="a7b1" style="display:none">
#       <p> 7 * 1 = 7 </p>
#     </div>
#
#     <div name="a7b2" style="display:none">
#       <p> 7 * 2 = 14 </p>
#     </div>
#
#     <div name="a7b3" style="display:none">
#       <p> 7 * 3 = 21 </p>
#     </div>
#
#     <div name="a7b4" style="display:none">
#       <p> 7 * 4 = 28 </p>
#     </div>
#
#     <div name="a7b5" style="display:none">
#       <p> 7 * 5 = 35 </p>
#     </div>
#
#     <div name="a7b6" style="display:none">
#       <p> 7 * 6 = 42 </p>
#     </div>
#
#     <div name="a7b7" style="display:none">
#       <p> 7 * 7 = 49 </p>
#     </div>
#
#     <div name="a7b8" style="d

# %% [markdown]
# ## Example 2: Text Output with Multiple Widgets

# %%
from ipywidgets import StaticInteract, RangeWidget, RadioWidget

def operation(a, b, op):
    if op == "multiply":
        return "{0} * {1} = {2}".format(a, b, a * b)
    elif op == "add":
        return "{0} + {1} = {2}".format(a, b, a + b)
    else:
        raise ValueError

StaticInteract(operation,
               a=RangeWidget(0, 10),
               b=RangeWidget(0, 10),
               op=RadioWidget(["multiply", "add"]))
# Out:
#     <script type="text/javascript">
#       function interactUpdate(div){
#          var outputs = div.getElementsByTagName("div");
#          var controls = div.getElementsByTagName("input");
#
#          var value = "";
#          for(i=0; i<controls.length; i++){
#            if((controls[i].type == "range") || controls[i].checked){
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }
#          }
#
#          for(i=0; i<outputs.length; i++){
#            var name = outputs[i].getAttribute("name");
#            if(name == value){
#               outputs[i].style.display = 'block';
#            } else if(name != "controls"){
#               outputs[i].style.display = 'none';
#            }
#          }
#       }
#     </script>
#
#     <div>
#
#     <div name="a0b0opmultiply" style="display:block">
#       <p> 0 * 0 = 0 </p>
#     </div>
#
#     <div name="a0b0opadd" style="display:none">
#       <p> 0 + 0 = 0 </p>
#     </div>
#
#     <div name="a0b1opmultiply" style="display:none">
#       <p> 0 * 1 = 0 </p>
#     </div>
#
#     <div name="a0b1opadd" style="display:none">
#       <p> 0 + 1 = 1 </p>
#     </div>
#
#     <div name="a0b2opmultiply" style="display:none">
#       <p> 0 * 2 = 0 </p>
#     </div>
#
#     <div name="a0b2opadd" style="display:none">
#       <p> 0 + 2 = 2 </p>
#     </div>
#
#     <div name="a0b3opmultiply" style="display:none">
#       <p> 0 * 3 = 0 </p>
#     </div>
#
#     <div name="a0b3opadd" style="display:none">
#       <p> 0 + 3 = 3 </p>
#     </div>
#
#     <div name="a0b4opmultiply" style="display:none">
#       <p> 0 * 4 = 0 </p>
#     </div>
#
#     <div name="a0b4opadd" style="display:none">
#       <p> 0 + 4 = 4 </p>
#     </div>
#
#     <div name="a0b5opmultiply" style="display:none">
#       <p> 0 * 5 = 0 </p>
#     </div>
#
#     <div name="a0b5opadd" style="display:none">
#       <p> 0 + 5 = 5 </p>
#     </div>
#
#     <div name="a0b6opmultiply" style="display:none">
#       <p> 0 * 6 = 0 </p>
#     </div>
#
#     <div name="a0b6opadd" style="display:none">
#       <p> 0 + 6 = 6 </p>
#     </div>
#
#     <div name="a0b7opmultiply" style="display:none">
#       <p> 0 * 7 = 0 </p>
#     </div>
#
#     <div name="a0b7opadd" style="display:none">
#       <p> 0 + 7 = 7 </p>
#     </div>
#
#     <div name="a0b8opmultiply" style="display:none">
#       <p> 0 * 8 = 0 </p>
#     </div>
#
#     <div name="a0b8opadd" style="display:none">
#       <p> 0 + 8 = 8 </p>
#     </div>
#
#     <div name="a0b9opmultiply" style="display:none">
#       <p> 0 * 9 = 0 </p>
#     </div>
#
#     <div name="a0b9opadd" style="display:none">
#       <p> 0 + 9 = 9 </p>
#     </div>
#
#     <div name="a0b10opmultiply" style="display:none">
#       <p> 0 * 10 = 0 </p>
#     </div>
#
#     <div name="a0b10opadd" style="display:none">
#       <p> 0 + 10 = 10 </p>
#     </div>
#
#     <div name="a1b0opmultiply" style="display:none">
#       <p> 1 * 0 = 0 </p>
#     </div>
#
#     <div name="a1b0opadd" style="display:none">
#       <p> 1 + 0 = 1 </p>
#     </div>
#
#     <div name="a1b1opmultiply" style="display:none">
#       <p> 1 * 1 = 1 </p>
#     </div>
#
#     <div name="a1b1opadd" style="display:none">
#       <p> 1 + 1 = 2 </p>
#     </div>
#
#     <div name="a1b2opmultiply" style="display:none">
#       <p> 1 * 2 = 2 </p>
#     </div>
#
#     <div name="a1b2opadd" style="display:none">
#       <p> 1 + 2 = 3 </p>
#     </div>
#
#     <div name="a1b3opmultiply" style="display:none">
#       <p> 1 * 3 = 3 </p>
#     </div>
#
#     <div name="a1b3opadd" style="display:none">
#       <p> 1 + 3 = 4 </p>
#     </div>
#
#     <div name="a1b4opmultiply" style="display:none">
#       <p> 1 * 4 = 4 </p>
#     </div>
#
#     <div name="a1b4opadd" style="display:none">
#       <p> 1 + 4 = 5 </p>
#     </div>
#
#     <div name="a1b5opmultiply" style="display:none">
#       <p> 1 * 5 = 5 </p>
#     </div>
#
#     <div name="a1b5opadd" style="display:none">
#       <p> 1 + 5 = 6 </p>
#     </div>
#
#     <div name="a1b6opmultiply" style="display:none">
#       <p> 1 * 6 = 6 </p>
#     </div>
#
#     <div name="a1b6opadd" style="display:none">
#       <p> 1 + 6 = 7 </p>
#     </div>
#
#     <div name="a1b7opmultiply" style="display:none">
#       <p> 1 * 7 = 7 </p>
#     </div>
#
#     <div name="a1b7opadd" style="display:none">
#       <p> 1 + 7 = 8 </p>
#     </div>
#
#     <div name="a1b8opmultiply" style="display:none">
#       <p> 1 * 8 = 8 </p>
#     </div>
#
#     <div name="a1b8opadd" style="display:none">
#       <p> 1 + 8 = 9 </p>
#     </div>
#
#     <div name="a1b9opmultiply" style="display:none">
#       <p> 1 * 9 = 9 </p>
#     </div>
#
#     <div name="a1b9opadd" style="display:none">
#       <p> 1 + 9 = 10 </p>
#     </div>
#
#     <div name="a1b10opmultiply" style="display:none">
#       <p> 1 * 10 = 10 </p>
#     </div>
#
#     <div name="a1b10opadd" style="display:none">
#       <p> 1 + 10 = 11 </p>
#     </div>
#
#     <div name="a2b0opmultiply" style="display:none">
#       <p> 2 * 0 = 0 </p>
#     </div>
#
#     <div name="a2b0opadd" style="display:none">
#       <p> 2 + 0 = 2 </p>
#     </div>
#
#     <div name="a2b1opmultiply" style="display:none">
#       <p> 2 * 1 = 2 </p>
#     </div>
#
#     <div name="a2b1opadd" style="display:none">
#       <p> 2 + 1 = 3 </p>
#     </div>
#
#     <div name="a2b2opmultiply" style="display:none">
#       <p> 2 * 2 = 4 </p>
#     </div>
#
#     <div name="a2b2opadd" style="display:none">
#       <p> 2 + 2 = 4 </p>
#     </div>
#
#     <div name="a2b3opmultiply" style="display:none">
#       <p> 2 * 3 = 6 </p>
#     </div>
#
#     <div name="a2b3opadd" style="display:none">
#       <p> 2 + 3 = 5 </p>
#     </div>
#
#     <div name="a2b4opmultiply" style="display:none">
#       <p> 2 * 4 = 8 </p>
#     </div>
#
#     <div name="a2b4opadd" style="display:none">
#       <p> 2 + 4 = 6 </p>
#     </div>
#
#     <div name="a2b5opmultiply" style="display:none">
#       <p> 2 * 5 = 10 </p>
#     </div>
#
#     <div name="a2b5opadd" style="display:none">
#       <p> 2 + 5 = 7 </p>
#     </div>
#
#     <div name="a2b6opmultiply" style="display:none">
#       <p> 2 * 6 = 12 </p>
#     </div>
#
#     <div name="a2b6opadd" style="display:none">
#       <p> 2 + 6 = 8 </p>
#     </div>
#
#     <div name="a2b7opmultiply" style="display:none">
#       <p> 2 * 7 = 14 </p>
#     </div>
#
#     <div name="a2b7opadd" style="display:none">
#       <p> 2 + 7 = 9 </p>
#     </div>
#
#     <div name="a2b8opmultiply" style="display:none">
#       <p> 2 * 8 = 16 </p>
#     </div>
#
#     <div name="a2b8opadd" style="display:none">
#       <p> 2 + 8 = 10 </p>
#     </div>
#
#     <div name="a2b9opmultiply" style="display:none">
#       <p> 2 * 9 = 18 </p>
#     </div>
#
#     <div name="a2b9opadd" style="display:none">
#       <p> 2 + 9 = 11 </p>
#     </div>
#
#     <div name="a2b10opmultiply" style="display:none">
#       <p> 2 * 10 = 20 </p>
#     </div>
#
#     <div name="a2b10opadd" style="display:none">
#       <p> 2 + 10 = 12 </p>
#     </div>
#
#     <div name="a3b0opmultiply" style="display:none">
#       <p> 3 * 0 = 0 </p>
#     </div>
#
#     <div name="a3b0opadd" style="display:none">
#       <p> 3 + 0 = 3 </p>
#     </div>
#
#     <div name="a3b1opmultiply" style="display:none">
#       <p> 3 * 1 = 3 </p>
#     </div>
#
#     <div name="a3b1opadd" style="display:none">
#       <p> 3 + 1 = 4 </p>
#     </div>
#
#     <div name="a3b2opmultiply" style="display:none">
#       <p> 3 * 2 = 6 </p>
#     </div>
#
#     <div name="a3b2opadd" style="display:none">
#       <p> 3 + 2 = 5 </p>
#     </div>
#
#     <div name="a3b3opmultiply" style="display:none">
#       <p> 3 * 3 = 9 </p>
#     </div>
#
#     <div name="a3b3opadd" style="display:none">
#       <p> 3 + 3 = 6 </p>
#     </div>
#
#     <div name="a3b4opmultiply" style="display:none">
#       <p> 3 * 4 = 12 </p>
#     </div>
#
#     <div name="a3b4opadd" style="display:none">
#       <p> 3 + 4 = 7 </p>
#     </div>
#
#     <div name="a3b5opmultiply" style="display:none">
#       <p> 3 * 5 = 15 </p>
#     </div>
#
#     <div name="a3b5opadd" style="display:none">
#       <p> 3 + 5 = 8 </p>
#     </div>
#
#     <div name="a3b6opmultiply" style="display:none">
#       <p> 3

# %% [markdown]
# ## Example 3: Sympy Factoring

# %%
from sympy import init_printing
init_printing()

# %%
from sympy import Symbol, Eq, factor
x = Symbol('x')
def factorit(n):
    return Eq(x ** n - 1, factor(x ** n - 1))
factorit(4)
# Out:
#  4                       ⎛ 2    ⎞
# x  - 1 = (x - 1)⋅(x + 1)⋅⎝x  + 1⎠

# %%
from ipywidgets import StaticInteract, RangeWidget

StaticInteract(factorit,
               n=RangeWidget(2, 10))
# Out:
#     <script type="text/javascript">
#       function interactUpdate(div){
#          var outputs = div.getElementsByTagName("div");
#          var controls = div.getElementsByTagName("input");
#
#          var value = "";
#          for(i=0; i<controls.length; i++){
#            if((controls[i].type == "range") || controls[i].checked){
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }
#          }
#
#          for(i=0; i<outputs.length; i++){
#            var name = outputs[i].getAttribute("name");
#            if(name == value){
#               outputs[i].style.display = 'block';
#            } else if(name != "controls"){
#               outputs[i].style.display = 'none';
#            }
#          }
#       }
#     </script>
#
#     <div>
#
#     <div name="n2" style="display:block">
#       <img src="...">
#     </div>
#
#     <div name="n3" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="n4" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="n5" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="n6" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="n7" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="n8" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="n9" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="n10" style="display:none">
#       <img src="...">
#     </div>
#
#       <input type="range" name="n" min="2" max="10" step="1" value="2" style="width:350px" onchange="interactUpdate(this.parentNode);">
#     </div>

# %% [markdown]
# ## Example 4: Matplotlib Figures

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from ipywidgets import StaticInteract, RangeWidget, RadioWidget

def plot(amplitude, color):
    fig, ax = plt.subplots(figsize=(4, 3),
                           subplot_kw={'axisbg':'#EEEEEE',
                                       'axisbelow':True})
    ax.grid(color='w', linewidth=2, linestyle='solid')
    x = np.linspace(0, 10, 1000)
    ax.plot(x, amplitude * np.sin(x), color=color,
            lw=5, alpha=0.4)
    ax.set_xlim(0, 10)
    ax.set_ylim(-1.1, 1.1)
    return fig

StaticInteract(plot,
               amplitude=RangeWidget(0.1, 1.0, 0.1),
               color=RadioWidget(['blue', 'green', 'red']))
# Out:
#     <script type="text/javascript">
#       function interactUpdate(div){
#          var outputs = div.getElementsByTagName("div");
#          var controls = div.getElementsByTagName("input");
#
#          var value = "";
#          for(i=0; i<controls.length; i++){
#            if((controls[i].type == "range") || controls[i].checked){
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }
#          }
#
#          for(i=0; i<outputs.length; i++){
#            var name = outputs[i].getAttribute("name");
#            if(name == value){
#               outputs[i].style.display = 'block';
#            } else if(name != "controls"){
#               outputs[i].style.display = 'none';
#            }
#          }
#       }
#     </script>
#
#     <div>
#
#     <div name="colorblueamplitude0.1" style="display:block">
#       <img src="...">
#     </div>
#
#     <div name="colorblueamplitude0.2" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="colorblueamplitude0.3" style="display:none">
#       <img src="...">
#     </div>
#
#     <div name="colorblueamplitude0.4" style="display:none">
#       <img src="...
